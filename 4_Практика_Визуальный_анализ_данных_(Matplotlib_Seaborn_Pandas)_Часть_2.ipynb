# %% [markdown]
# <a href="https://colab.research.google.com/github/vladtsyp/study_datamining/blob/main/4_%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0_%D0%92%D0%B8%D0%B7%D1%83%D0%B0%D0%BB%D1%8C%D0%BD%D1%8B%D0%B9_%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D0%B7_%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85_(Matplotlib_Seaborn_Pandas)_%D0%A7%D0%B0%D1%81%D1%82%D1%8C_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Практика. Визуальный анализ данных (Matplotlib/Seaborn/Pandas). Часть 2
#
#
# 1. Скачайте этот блокнот к себе.
# 2. Заполните пропущенные ячейки, отвечая на заданные вопросы. Там должен быть код! (если не сказано обратное)
# 3. Сохраните результат в своём репозитории.
#
# #### Полезная литература
# - [**Блокнот с теорией**](https://colab.research.google.com/github/Alexandre77777/data_mining/blob/main/1.%20%D0%92%D0%B2%D0%B5%D0%B4%D0%B5%D0%BD%D0%B8%D0%B5/%D0%A2%D0%B5%D0%BE%D1%80%D0%B8%D1%8F/3.%20%D0%A2%D0%B5%D0%BE%D1%80%D0%B8%D1%8F_Matplotlib_Seaborn_Plotly.ipynb)
# - [Галерея графиков Matplotlib](https://matplotlib.org/gallery/index.html)
# - [Галерея графиков Seaborn](http://seaborn.pydata.org/examples/index.html)
# - [Открытый курс машинного обучения. Тема 2: Визуализация данных c Python](https://habr.com/company/ods/blog/323210/)

# %%
# !pip install seaborn==0.11.0
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Requirement already satisfied: seaborn==0.11.0 in /usr/local/lib/python3.10/dist-packages (0.11.0)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.10/dist-packages (from seaborn==0.11.0) (1.23.5)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from seaborn==0.11.0) (1.11.2)
# Requirement already satisfied: pandas>=0.23 in /usr/local/lib/python3.10/dist-packages (from seaborn==0.11.0) (1.5.3)
# Requirement already satisfied: matplotlib>=2.2 in /usr/local/lib/python3.10/dist-packages (from seaborn==0.11.0) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2->seaborn==0.11.0) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2->seaborn==0.11.0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2->seaborn==0.11.0) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2->seaborn==0.11.0) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2->seaborn==0.11.0) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2->seaborn==0.11.0) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2->seaborn==0.11.0) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2->seaborn==0.11.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23->seaborn==0.11.0) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn==0.11.0) (1.16.0)

# %%
colab = False # если работаете на своём компьютере, поставьте False
if colab:
    from google.colab import drive
    drive.mount('/content/drive')

# %% [markdown]
# ## Визуальный анализ данных
#
# В этом задании вам предлагается провести визуальный анализ датасета результатов экзаменов студентов  https://www.kaggle.com/spscientist/students-performance-in-exams.

# %%
if colab:
    df = pd.read_csv('/content/drive/My Drive/Data/StudentsPerformance.csv')
else:
    df = pd.read_csv("StudentsPerformance.csv")

df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %% [markdown]
# ## Задания
# #### 1. Постройте 3 графика, показывающих распределение результатов экзаменов (каждый график на предмет).
#
#
# Графики должны быть в одном ряду и у них должен быть общий заголовок "Результаты экзаменов".
#
# Для результатов каждого экзамена посчитайте медианные значения.

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 3))
fig.suptitle('Результаты экзаменов')

sns.distplot(ax=axes[0], a=df['math score'].dropna())
sns.distplot(ax=axes[1], a=df['reading score'].dropna())
sns.distplot(ax=axes[2], a=df['writing score'].dropna())
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <Axes: xlabel='writing score', ylabel='Density'>

# %%
print(df[['math score', 'reading score', 'writing score']].median())
# Out:
# math score       66.0
# reading score    70.0
# writing score    69.0
# dtype: float64

# %% [markdown]
# #### 2. Образование родителей
# Какие уровни образование есть в столбце *'parental level of education'* и сколько строк в датафрейме соответствует каждому уровню?
#
# Постройте график и ответьте на вопрос ниже
#
# Отличаются ли баллы по математике у детей с разным образованием родителей?
# Постройте график, где по оси Х находятся уровни образования родителей, а по У - баллы по математике.

# %%
sns.countplot(y=df['parental level of education'])
# Out:
# <Axes: xlabel='count', ylabel='parental level of education'>

# %%
sns.boxplot(y=df['parental level of education'], x=df['math score'])
# Out:
# <Axes: xlabel='math score', ylabel='parental level of education'>

# %% [markdown]
# #### 3. Выведите число студенток, набравших больше 90 баллов по всем предметам.

# %%
print(df[(df['gender'] == 'female') & (df['math score'] > 90) & (df['reading score'] > 90) & (df['writing score'] > 90)].shape)
# Out:
# (17, 8)

# %%
df[(df['gender'] == 'female') & (df['math score'] > 90) & (df['reading score'] > 90) & (df['writing score'] > 90)]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 114  female        group E           bachelor's degree      standard
# 165  female        group C           bachelor's degree      standard
# 179  female        group D            some high school      standard
# 451  female        group E                some college      standard
# 458  female        group E           bachelor's degree      standard
# 546  female        group A            some high school      standard
# 566  female        group E           bachelor's degree  free/reduced
# 594  female        group C           bachelor's degree      standard
# 685  female        group E             master's degree      standard
# 712  female        group D                some college      standard
# 717  female        group C          associate's degree      standard
# 855  female        group B           bachelor's degree      standard
# 886  female        group E          associate's degree      standard
# 903  female        group D           bachelor's degree  free/reduced
# 957  female        group D             master's degree      standard
# 962  female        group E          associate's degree      standard
# 979  female        group C          associate's degree      standard
#
#     test preparation course  math score  reading score  writing score
# 114               completed          99            100            100
# 165               completed          96            100            100
# 179               completed          97            100            100
# 451                    none         100             92             97
# 458                    none         100            100            100
# 546               completed          92            100             97
# 566               completed          92            100            100
# 594               completed          92            100             99
# 685               completed          94             99            100
# 712                    none          98            100             99
# 717               completed          96             96             99
# 855                    none          97             97             96
# 886               completed          93            100             95
# 903               completed          93            100            100
# 957                    none          92            100            100
# 962                    none         100            100            100
# 979                    none          91             95             94

# %% [markdown]
# #### 4. Сравните баллы у студентов разных полов. Используя agg() выведите минимальное, максимальное и медианное значение

# %%
df[df['gender'] == 'male'][['math score', 'reading score', 'writing score']].agg(['min', 'max', 'median'])
# Out:
#         math score  reading score  writing score
# min           27.0           23.0           15.0
# max          100.0          100.0          100.0
# median        69.0           66.0           64.0

# %%
df[df['gender'] == 'female'][['math score', 'reading score', 'writing score']].agg(['min', 'max', 'median'])
# Out:
#         math score  reading score  writing score
# min            0.0           17.0           10.0
# max          100.0          100.0          100.0
# median        65.0           73.0           74.0

# %% [markdown]
# #### 5. Выясните, влияет ли обед и подготовка к тесту на средний балл студентов разного пола
# ###### (подсказка: используете agg())

# %%
df.groupby(['lunch', 'test preparation course']).agg(['mean'])
# Out:
# <ipython-input-15-7398addd6fa7>:1: FutureWarning: ['gender', 'race/ethnicity', 'parental level of education'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df.groupby(['lunch', 'test preparation course']).agg(['mean'])
#                                      math score reading score writing score
#                                            mean          mean          mean
# lunch        test preparation course
# free/reduced completed                63.045802     69.870229     70.351145
#              none                     56.508929     61.602679     58.736607
# standard     completed                73.533040     76.215859     76.766520
#              none                     68.133971     69.177033     67.595694

# %% [markdown]
# #### 6. Постройте график, показывающий зависимость уровня образования родителей от их расы

# %%
sns.countplot(y=df['parental level of education'], hue=df['race/ethnicity'])
# Out:
# <Axes: xlabel='count', ylabel='parental level of education'>

# %% [markdown]
# #### 7. Постройте график, показывающий зависимость прохождения подготовительного теста от уровня образования родителей.
#
#
# Кто чаще ходит на курсы: дети, родители которых закончили только старшую школу, или дети, чьи родители получили степень бакалавра\магистра?

# %%
sns.countplot(x=df['test preparation course'], hue=df['parental level of education'])
# Out:
# <Axes: xlabel='test preparation course', ylabel='count'>

# %% [markdown]
# #### 8. Постройте plot.pie, показывающий, сколько людей сдали\не сдали экзамен по математике.
#
# Сдавшим считается человек, набравший 40 баллов.
#
# ###### Подсказка: создайте столбец в датафрейме, который содержит результат сдачи (сдал или не сдал)

# %%
(df['math score'] > 40).value_counts().plot.pie(y='math score')
# Out:
# <Axes: ylabel='math score'>

# %% [markdown]
# #### 9. Постройте plot.pie, показывающий распределение студентов по оценкам
#
# Оценки студентов выставляются по шкале:<br>
# 0  - 40 marks : grade E<br>
# 41 - 60 marks : grade D<br>
# 60 - 70 marks : grade C<br>
# 70 - 80 marks : grade B<br>
# 80 - 90 marks : grade A<br>
# 90 - 100 marks : grade O<br>
#
# Для этого посчитайте сумму результатов за 3 экзамена и найдите среднее. Оценка выставляется по среднему значению. Если студент не сдал математику(даже если средний балл выше 40), он получает Е

# %%
def grading(row):
  if row['math score'] < 40:
    return 'grade E'
  else:
    summary = (row['math score'] + row['reading score'] + row['writing score']) / 3
    if summary <= 40:
      return 'grade E'
    elif 41 <= summary < 60:
      return 'grade D'
    elif 60 <= summary < 70:
      return 'grade C'
    elif 70 <= summary < 80:
      return 'grade B'
    elif 80 <= summary < 90:
      return 'grade A'
    elif 90 <= summary <= 100:
      return 'grade O'

df['grade'] = df.apply(lambda row: grading(row), axis = 1)
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score    grade
# 0                      none          72             72             74  grade B
# 1                 completed          69             90             88  grade A
# 2                      none          90             95             93  grade O
# 3                      none          47             57             44  grade D
# 4                      none          76             78             75  grade B
# ..                      ...         ...            ...            ...      ...
# 995               completed          88             99             95  grade O
# 996                    none          62             55             55  grade D
# 997               completed          59             71             65  grade C
# 998               completed          68             78             77  grade B
# 999                    none          77             86             86  grade A
#
# [1000 rows x 9 columns]

# %%
df['grade'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='grade'>

# %% [markdown]
# #### 10. Постройте countplot, показывающий зависимость между итоговой оценкой студентов и его полом. Студенты какого пола получили больше оценок О, А, В

# %%
sns.countplot(x='gender', hue='grade', data=df)
# ответ: female
# Out:
# <Axes: xlabel='gender', ylabel='count'>
